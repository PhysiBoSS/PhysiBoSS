# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# ECM:
# ecm_data = pd.read_csv('../config/initial_cond/cylinder_unit_ecm_2D_doble.tsv', sep='\t', header=0)
# ecm_data = pd.read_csv('../config/initial_cond/cylinder_unit_ecm_2D_40_doble.tsv', sep='\t', header=0)
ecm_data = pd.read_csv('../config/initial_cond/spatial_ecm.tsv', sep='\t', header=None, names=['x', 'y', 'z'])
# cylinder: Filter data where z=0
ecm_data_filtered = ecm_data[ecm_data['z'] == 0]
# spatial: Filter data where z=7, the midpoint
ecm_data_filtered = ecm_data[ecm_data['z'] == 7]


# cells:
# Read the data file (assuming it's comma or space separated)
# cells_data = pd.read_csv('../config/initial_cond/cylinder_unit_cells_2D_330.csv', sep=',', header=None, names=['x', 'y', 'z', 'type'])
cells_data = pd.read_csv('../config/initial_cond/spatial_cells.csv', sep=',', header=None, names=['x', 'y', 'z', 'type'])
cells_data[['x']] = (((cells_data[['x']] - 10) / 20) + 20).astype(int)
cells_data[['y']] = (((cells_data[['y']] - 10) / 20) + 20).astype(int)
cells_data[['z']] = (((cells_data[['z']] - 10) / 20) + 0).astype(int)
# cylinder: Filter data where z=2 which is 5 in the other datasets
# cells_data_filtered = cells_data[cells_data['z'] == 0]
# spatial: Filter data where z=10, the closest to the mid point
cells_data_filtered = cells_data[cells_data['z'] == 10]

# endothelium:
# endo_data = pd.read_csv('../config/initial_cond/cylinder_unit_endo_2D.tsv', sep='\t', header=0)
# endo_data = pd.read_csv('../config/initial_cond/cylinder_unit_endo_2D_40.tsv', sep='\t', header=0)
endo_data = pd.read_csv('../config/initial_cond/spatial_endo.tsv', sep='\t', header=None, names=['x', 'y', 'z'])
endo_data[['x']] = (endo_data[['x']] - 1).astype(int)
# cylinder: Filter data where z=0
# endo_data_filtered = endo_data[endo_data['z'] == 0]
# spatial: Filter data where z=7, the midpoint
endo_data_filtered = endo_data[endo_data['z'] == 7]

# %%
print(sorted(ecm_data['z'].unique())) 
print(sorted(cells_data['z'].unique()))
print(sorted(endo_data['z'].unique()))
# Out:
# [np.int64(0), np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6), np.int64(7), np.int64(8), np.int64(9), np.int64(10), np.int64(11), np.int64(12), np.int64(13)]
# [np.int64(-2), np.int64(-1), np.int64(0), np.int64(1), np.int64(2)]
# [np.int64(5), np.int64(6), np.int64(7), np.int64(8), np.int64(9)]

# %%
# print(sorted(ecm_data['x'].unique())) 
# print(sorted(endo_data['x'].unique()))
print(sorted(cells_data['x'].unique()))
# print(sorted(ecm_data['y'].unique())) 
# print(sorted(endo_data['y'].unique()))
print(sorted(cells_data['y'].unique()))
print(sorted(cells_data['z'].unique()))

# print(cells_data['x'].describe())
# print(cells_data['x'].value_counts().sort_index())
# Out:
# [np.int64(-39), np.int64(-38), np.int64(-37), np.int64(-36), np.int64(-35), np.int64(-34), np.int64(-33), np.int64(-32), np.int64(-31), np.int64(-30), np.int64(-29), np.int64(-28), np.int64(-27), np.int64(-26), np.int64(-25), np.int64(-24), np.int64(-23), np.int64(-22), np.int64(-21), np.int64(-20), np.int64(-19), np.int64(-18), np.int64(-17), np.int64(-16), np.int64(-15), np.int64(-14), np.int64(-13), np.int64(-12), np.int64(-11), np.int64(-10), np.int64(-9), np.int64(-8), np.int64(-7), np.int64(-6), np.int64(-5), np.int64(-4), np.int64(-3), np.int64(-2), np.int64(-1), np.int64(0), np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6), np.int64(7), np.int64(8), np.int64(9), np.int64(10), np.int64(11), np.int64(12), np.int64(13), np.int64(14), np.int64(15), np.int64(16), np.int64(17), np.int64(18), np.int64(19), np.int64(20), np.int64(21), np.int64(22), np.int64(23), np.int64(24), np.int64(25), np.int64(26), np.int64(27), np.int64(28), np.int64(29), np.int64(30), np.int64(31), np.int64(32), np.int64(33), np.int64(34), np.int64(35), np.int64(36), np.int64(37), np.int64(38), np.int64(39), np.int64(40), np.int64(41), np.int64(42), np.int64(43), np.int64(44), np.int64(45), np.int64(46), np.int64(47), np.int64(48), np.int64(49), np.int64(50), np.int64(51), np.int64(52), np.int64(53), np.int64(54), np.int64(55), np.int64(56), np.int64(57), np.int64(58), np.int64(59), np.int64(60), np.int64(61), np.int64(62), np.int64(63), np.int64(64), np.int64(65), np.int64(66), np.int64(67), np.int64(68), np.int64(69), np.int64(70), np.int64(71), np.int64(72), np.int64(73), np.int64(74), np.int64(75), np.int64(76), np.int64(77), np.int64(78), np.int64(79)]
# [np.int64(-18), np.int64(-17), np.int64(-16), np.int64(-15), np.int64(-14), np.int64(-13), np.int64(-12), np.int64(-11), np.int64(-10), np.int64(-9), np.int64(-8), np.int64(-7), np.int64(-6), np.int64(-5), np.int64(-4), np.int64(-3), np.int64(-2), np.int64(-1), np.int64(0), np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6), np.int64(7), np.int64(8), np.int64(9), np.int64(10), np.int64(11), np.int64(12), np.int64(13), np.int64(14), np.int64(15), np.int64(16), np.int64(17), np.int64(18), np.int64(19), np.int64(20), np.int64(21), np.int64(22), np.int64(23), np.int64(24), np.int64(25), np.int64(26), np.int64(27), np.int64(28), np.int64(29), np.int64(30), np.int64(31), np.int64(32), np.int64(33), np.int64(34), np.int64(35), np.int64(36), np.int64(37), np.int64(38), np.int64(39), np.int64(40), np.int64(41), np.int64(42), np.int64(43), np.int64(44), np.int64(45), np.int64(46), np.int64(47), np.int64(48), np.int64(49), np.int64(50), np.int64(51), np.int64(52), np.int64(53), np.int64(54), np.int64(55), np.int64(56), np.int64(57), np.int64(58)]
# [np.int64(-2), np.int64(-1), np.int64(0), np.int64(1), np.int64(2)]

# %%
# Create a pivot table for the heatmap
# First find the dimensions of the grid
# x_max = int(ecm_data_filtered['x'].max())
# y_max = int(ecm_data_filtered['y'].max())
x_max = 40
y_max = 40

# Create an empty grid
grid = np.zeros((y_max + 1, x_max + 1))

# Fill the grid with 1s of ECM
for _, row in ecm_data_filtered.iterrows():
    grid[int(row['y']), int(row['x'])] = 1
    
# Fill the grid with 2s of endothelium
for _, row in endo_data_filtered.iterrows():
    grid[int(row['y']), int(row['x'])] = 2

# for _, row in cells_data_filtered.iterrows():
#     grid[int(row['y']), int(row['x'])] = 3
    
# Fill cells with different values based on their type
for _, row in cells_data_filtered.iterrows():
    # Assuming types start from 1, add an offset to distinguish from ECM and endothelium
    grid[int(row['y']), int(row['x'])] = row['type'] + 3

# %%
# Create custom colormap for different cell types
n_types = len(cells_data_filtered['type'].unique())
colors = ['white', '#FFF4C2', 'black'] + sns.color_palette("Set2", n_types).as_hex()
custom_cmap = plt.cm.colors.ListedColormap(colors)

# Create the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(grid, 
            cmap=custom_cmap,  
            cbar=False,     
            xticklabels=False, 
            yticklabels=False)

plt.gca().invert_yaxis()
plt.show()

# %%
cells_data_filtered2 = cells_data_filtered.copy()
cells_data_filtered2[['x']] = (((cells_data_filtered2[['x']] -36) * 20) + 10).astype(int)
cells_data_filtered2[['y']] = (((cells_data_filtered2[['y']] -36) * 20) + 10).astype(int)
cells_data_filtered2[['z']] = (((cells_data_filtered2[['z']] -3) * 20) + 30).astype(int)
# cells_data_filtered[['y']] = (((cells_data_filtered[['y']] - 10) / 20) + 36).astype(int)
# cells_data_filtered[['z']] = (((cells_data_filtered[['z']] - 10) / 20) + 3).astype(int)


print(sorted(cells_data_filtered2['x'].unique()))
print(sorted(cells_data_filtered2['y'].unique()))
print(sorted(cells_data_filtered2['z'].unique()))

# %%
# ecm_data_filtered.to_csv('../config/cylinder_unit_ecm_2D.tsv', sep='\t', index=False)
# cells_data_filtered2.to_csv('../config/cylinder_unit_cells_2D.csv', sep=',', index=False)
# endo_data_filtered.to_csv('../config/cylinder_unit_endo_2D.tsv', sep='\t', index=False)
